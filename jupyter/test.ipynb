# %%
# %load_ext autoreload
# %autoreload 2
import single_cell_datasets
import datalair
import anndata as ad
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
lair = datalair.Lair("/storage/halu/lair")
lair.assert_ok_satus()

# %%
for f in infiles:
    import anndata as ad
    metadata = ad.read_h5ad(f, backed='r')
    if "paitent" not in metadata.obs.columns:
        continue
    print(f"{f}: {metadata.obs['patient'].dtype}")
    # Also check for nulls
    print(metadata.obs['patient'].isna().sum())

# %%
ad.experimental.concat_on_disk(infiles, "/tmp/adata.h5ad", join="inner", axis=0)

# %%
adata = ad.read_h5ad("/tmp/adata.h5ad")
# Out:
# /home/halu/python-venv/tme_analysis/.venv/lib/python3.14/site-packages/anndata/_core/anndata.py:1823: UserWarning: Observation names are not unique. To make them unique, call `.obs_names_make_unique`.
#   utils.warn_names_duplicates("obs")

# %%
adata.X.sum(axis=1).max()
# Out:
# np.int64(6684347)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2380065 × 41841
#     obs: 'cancer_code', 'staging', 'dataset', 'n_genes'
